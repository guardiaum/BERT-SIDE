# %% [markdown]
# <a href="https://colab.research.google.com/github/guardiaum/BERT-SIDE/blob/master/bert_side.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os, sys, random, argparse
import pickle
from collections import defaultdict as ddict
import tensorflow as tf
from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform, randint
from sklearn import metrics
from sklearn.metrics import precision_recall_curve, average_precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import auc
import matplotlib.pyplot as plt

# Set precision for numpy
np.set_printoptions(precision=4)

seed = 1234

tf.random.set_seed(seed)
random.seed(seed)
np.random.seed(seed)
# Out:
# Using TensorFlow backend.

# %%
dataset_name = "gids"
path2datafile = "data/{}_bert_processed.pkl".format(dataset_name)
models_dir = "models/"
results_dir = "results/{}/".format(dataset_name)

model_name = '{}_best_model'.format(dataset_name)

# %%
def padData(data, max_sent_in_bag, max_alias, max_alias_len, subj_max, obj_max, aliases_count):
    dataset = []
    countBags = 0
    
    for i, bag in enumerate(data):
        embeds = bag['embeds']
        aliases = bag['ProbY']
        sub_type = bag['SubType']
        obj_type = bag['ObjType']
        
        # padding embeds
        while len(embeds) != max_sent_in_bag:
            embeds.append(np.zeros(768))
        
        # padding alias
        while len(aliases) != max_sent_in_bag:
            aliases.append([0])
              
        pad_alias = np.zeros((len(aliases), max_alias), np.int32)
        for i, alias in enumerate(aliases):
            pad_alias[i, :len(alias)] = alias[:max_alias]
        
        # padding subject
        while len(sub_type) != subj_max:
            sub_type.append(0)
            
        # padding object
        while len(obj_type) != obj_max:
            obj_type.append(0)
        
        label = bag['Y']
        
        while len(label) > 1:
            label.pop()
        
        dataset.append([embeds, pad_alias, sub_type, obj_type, label])
        countBags += 1
        
    return dataset, countBags, aliases_count
    

def getData(data):
    max_sent_in_bag, max_alias, max_alias_len, subj_max, obj_max, aliases_count = 0, 0, 0, 0, 0, 0 
    
    for i, bag in enumerate(data):
        embeds = bag['embeds']
        aliases = bag['ProbY']
        sub_type = bag['SubType']
        obj_type = bag['ObjType']
        
        max_sent_in_bag = max(max_sent_in_bag, len(embeds))
        
        max_alias = max(max_alias, len(aliases))
        
        for alias in aliases:
            max_alias_len = max(max_alias_len, len(alias))
            for a in alias:
                aliases_count = max(aliases_count, a)
            
        subj_max = max(subj_max, len(sub_type))
        obj_max = max(obj_max, len(obj_type))
    
    return padData(data, max_sent_in_bag, max_alias, max_alias_len, subj_max, obj_max, aliases_count+1)

# %%
def data(path2datafile, models_dir, model_name):
    batch_size = 512
    type_dim = 150
    alias_dim = 150
    embedding_dim = 768
    L2 = 0.001
    regularizer = tf.keras.regularizers.l2(l=0.5 * (L2))

    data = pickle.load(open(path2datafile, 'rb'))

    voc2id      = data['voc2id']
    id2voc      = data['id2voc']
    type2id     = data['type2id']
    type_count  = len(data['type2id'])
    num_class   = len(data['rel2id'])
    max_pos = data['max_pos']
    
    print("getData Train")
    train, train_bags, alias_count = getData(data['train'])
    
    print("getData Validation")
    validation, test_bags, alias_count = getData(data['dev'])
    
    print("getData Test")
    test, dev_bags, alias_count = getData(data['test'])
    
    return train, validation, test, embedding_dim, num_class, alias_dim, regularizer, type_count, type_dim, batch_size, alias_count, models_dir, model_name

def get_chunks(data, batch_size):
    count_bags = len(data)
    for indx in range(0, count_bags, batch_size):
        yield data[indx:min(indx + batch_size, count_bags)]
        
def create_batches(data, batch_size=64):
    batches = []
    for chunk in get_chunks(data, batch_size):
        batch = ddict(list)
        num = 0
        
        bert = []
        alias = []
        subj = []
        obj = []
        out = []
        for i, bag in enumerate(chunk):
            bert.append(bag[0])
            alias.append(bag[1])
            subj.append(bag[2])
            obj.append(bag[3])
            out.append(bag[4])
        batches.append([bert, alias, subj, obj, out])
        
    return batches, len(batches)
    
def get_batches(batches):
    while True:
        for batch in batches:
            yield ({'bert_input': np.array(batch[0], dtype='float32'), 
                    'alias': np.array(batch[1], dtype='int32'), 
                    'subj': np.array(batch[2], dtype='int32'), 
                    'obj': np.array(batch[3], dtype='int32')}, 
                   {'output': np.array(batch[4], dtype='int32')})

# %%
def model(train, validation, test, embedding_dim, num_class, alias_dim, regularizer, 
          type_count, type_dim, batch_size, max_pos, alias_count, models_dir, model_name):
    
    # embed input
    embed_input = tf.keras.Input(shape=(None, embedding_dim,), name="bert_input", dtype='float32')
    
    # embed alias
    alias_input = tf.keras.Input(shape=(None, None,), name="alias", dtype='int32')
    embed_alias = tf.keras.layers.Embedding(input_dim=alias_count, 
                                            output_dim=alias_dim, trainable=True,
                                            embeddings_initializer=tf.keras.initializers.VarianceScaling(
                                                scale=1.0, mode="fan_avg", distribution="uniform"), 
                                            embeddings_regularizer=regularizer, name='alias_embed')(alias_input)
    
    alias_av = tf.math.reduce_sum(input_tensor=embed_alias, axis=2, keepdims=False, name='alias_mean') / tf.cast(tf.shape(embed_alias)[1], tf.float32)
    
    # sentence representations
    sent_reps = tf.keras.layers.concatenate([embed_input, alias_av], axis=2, name='bert_alias_concat')
    
    
    # Input subj-obj types
    subj_input = tf.keras.layers.Input(shape=(None,), name="subj", dtype='int32')
    obj_input = tf.keras.layers.Input(shape=(None,), name="obj", dtype='int32')
    
    # embed subj-obj types
    embed_type = tf.keras.layers.Embedding(input_dim=type_count, output_dim=type_dim, 
                                           embeddings_regularizer=regularizer,
                                           embeddings_initializer=tf.compat.v1.keras.initializers.VarianceScaling(
                                               scale=1.0, mode="fan_avg", distribution="uniform"), name='type_embed')
    subj_embed = embed_type(subj_input)
    obj_embed = embed_type(obj_input)
    
    # average of types representations
    subj_type_av = tf.math.reduce_mean(input_tensor=subj_embed, axis=1, name='subj_mean')
    obj_type_av = tf.math.reduce_mean(input_tensor=obj_embed, axis=1, name='obj_mean')
    
    # concatenate subject and object to one single representation
    concat_type = tf.keras.layers.concatenate([subj_type_av, obj_type_av], axis=1, name='type_concat')
    
    # weights for querying attention layer 
    # samples are drawn from a uniform distribution within [-limit, limit], with limit = sqrt(3 * scale / n)
    sent_atten_q = tf.keras.initializers.VarianceScaling(scale=1.0, 
                                                         mode="fan_avg", 
                                                         distribution="uniform")(shape=(1, 1, alias_dim+embedding_dim))  # alias_dim+
    
    # Bag Attention sentence level
    bag_attention = tf.keras.layers.Attention(name='attention')([sent_atten_q, sent_reps])
    
    mean_bag_attention = tf.math.reduce_mean(bag_attention, axis=1)
    
    bag_reps = tf.keras.layers.concatenate([mean_bag_attention, concat_type], axis=1, name='bag_rep_type_concat')
    
    # fully connected
    fc1 = tf.keras.layers.Dense(units={{choice([48, 96, 192, 384, 768])}}, 
                                activation="relu", 
                                kernel_regularizer=regularizer, name='fully1')(bag_reps)
    
    drop1 = tf.keras.layers.Dropout(rate={{uniform(0,1)}}, name='drop1')(fc1)
    
    fc2 = tf.keras.layers.Dense(units={{choice([6, 12, 24, 48])}}, 
                                activation="relu", 
                                kernel_regularizer=regularizer, name='fully2')(drop1)
    
    drop = tf.keras.layers.Dropout(rate={{uniform(0,1)}}, name='drop2')(fc2)
    
    # output layer
    label = tf.keras.layers.Dense(num_class, activation='softmax', kernel_regularizer=regularizer, name='output')(drop)
    
    model = tf.keras.Model([embed_input, alias_input, subj_input, obj_input], label)
    
    print(model.summary())
    
    optim = tf.keras.optimizers.SGD(lr={{uniform(0,1)}}, name='SGD')

    model.compile(loss=tf.keras.losses.sparse_categorical_crossentropy,
                  optimizer=optim,
                  metrics=['accuracy'])
    
    train_batches, train_batches_len = create_batches(train, batch_size)
    val_batches, val_batches_len = create_batches(validation, batch_size)
    test_batches, test_batches_len = create_batches(test, batch_size)
    
    checkpointer = tf.keras.callbacks.ModelCheckpoint(filepath=models_dir+ model_name + "-es_best.h5", verbose=1, 
                                   save_best_only=True, save_weights_only=True)
    earlystopper = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=40, verbose=1)
    
    history = model.fit_generator(get_batches(train_batches), steps_per_epoch=train_batches_len, 
                        epochs=500, verbose=2, validation_steps=val_batches_len, 
                        validation_data=get_batches(val_batches), callbacks=[checkpointer, earlystopper])
    
    score, acc = model.evaluate_generator(generator=get_batches(test_batches), 
                                          steps=test_batches_len, verbose=0)
    print('Test accuracy:', acc)
    
    return {'loss': -acc, 'status': STATUS_OK, 'model': model, 
            'history.val_loss':history.history['val_loss'], 
            'history.val_acc': history.history['val_accuracy'],
            'history.loss': history.history['loss'], 
            'history.acc': history.history['accuracy']}

# %%
# chose better parameters to model
trials = Trials()
best_run, best_model = optim.minimize(model=model,
                                      data=data,
                                      algo=tpe.suggest,
                                      max_evals=10,
                                      trials=trials,
                                      functions=[padData, getData, get_chunks, get_batches, create_batches],
                                      notebook_name='GIDS_bert_side',
                                      data_args=(path2datafile,models_dir, model_name)
                                      )

print("Best performing model chosen hyper-parameters:")
print(best_run)

tf.keras.utils.plot_model(best_model, to_file=models_dir + model_name + ".png", show_shapes=True, show_layer_names=True)
best_model.save(models_dir + model_name + '.h5')
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     from pydrive.auth import GoogleAuth
# except:
#     pass
#
# try:
#     from pydrive.drive import GoogleDrive
# except:
#     pass
#
# try:
#     from google.colab import auth
# except:
#     pass
#
# try:
#     from oauth2client.client import GoogleCredentials
# except:
#     pass
#
# try:
#     from google.colab import drive
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     import pandas as pd
# except:
#     pass
#
# try:
#     import os, sys, random, argparse
# except:
#     pass
#
# try:
#     import pickle
# except:
#     pass
#
# try:
#     from collections import defaultdict as ddict
# except:
#     pass
#
# try:
#     import tensorflow as tf
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform, randint
# except:
#     pass
#
# try:
#     from sklearn import metrics
# except:
#     pass
#
# try:
#     from sklearn.metrics import precision_recall_curve, average_precision_score
# except:
#     pass
#
# try:
#     from sklearn.metrics import f1_score
# except:
#     pass
#
# try:
#     from sklearn.metrics import auc
# except:
#     pass
#
# try:
#     import matplotlib.pyplot as plt
# except:
#     pass
#
# try:
#     import collections
# except:
#     pass
#
# try:
#     import matplotlib.pyplot as plt
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'units': hp.choice('units', [48, 96, 192, 384, 768]),
#         'rate': hp.uniform('rate', 0,1),
#         'units_1': hp.choice('units_1', [6, 12, 24, 48]),
#         'rate_1': hp.uniform('rate_1', 0,1),
#         'rate_2': hp.uniform('rate_2', 0,1),
#     }
#
# >>> Functions
#    1: def padData(data, max_sent_in_bag, max_alias, max_alias_len, subj_max, obj_max, aliases_count):
#    2:     dataset = []
#    3:     countBags = 0
#    4:
#    5:     for i, bag in enumerate(data):
#    6:         embeds = bag['embeds']
#    7:         aliases = bag['ProbY']
#    8:         sub_type = bag['SubType']
#    9:         obj_type = bag['ObjType']
#   10:
#   11:         # padding embeds
#   12:         while len(embeds) != max_sent_in_bag:
#   13:             embeds.append(np.zeros(768))
#   14:
#   15:         # padding alias
#   16:         while len(aliases) != max_sent_in_bag:
#   17:             aliases.append([0])
#   18:
#   19:         pad_alias = np.zeros((len(aliases), max_alias), np.int32)
#   20:         for i, alias in enumerate(aliases):
#   21:             pad_alias[i, :len(alias)] = alias[:max_alias]
#   22:
#   23:         # padding subject
#   24:         while len(sub_type) != subj_max:
#   25:             sub_type.append(0)
#   26:
#   27:         # padding object
#   28:         while len(obj_type) != obj_max:
#   29:             obj_type.append(0)
#   30:
#   31:         label = bag['Y']
#   32:
#   33:         while len(label) > 1:
#   34:             label.pop()
#   35:
#   36:         dataset.append([embeds, pad_alias, sub_type, obj_type, label])
#   37:         countBags += 1
#   38:
#   39:     return dataset, countBags, aliases_count
#   40:
#   41: def getData(data):
#   42:     max_sent_in_bag, max_alias, max_alias_len, subj_max, obj_max, aliases_count = 0, 0, 0, 0, 0, 0
#   43:
#   44:     for i, bag in enumerate(data):
#   45:         embeds = bag['embeds']
#   46:         aliases = bag['ProbY']
#   47:         sub_type = bag['SubType']
#   48:         obj_type = bag['ObjType']
#   49:
#   50:         max_sent_in_bag = max(max_sent_in_bag, len(embeds))
#   51:
#   52:         max_alias = max(max_alias, len(aliases))
#   53:
#   54:         for alias in aliases:
#   55:             max_alias_len = max(max_alias_len, len(alias))
#   56:             for a in alias:
#   57:                 aliases_count = max(aliases_count, a)
#   58:
#   59:         subj_max = max(subj_max, len(sub_type))
#   60:         obj_max = max(obj_max, len(obj_type))
#   61:
#   62:     return padData(data, max_sent_in_bag, max_alias, max_alias_len, subj_max, obj_max, aliases_count+1)
#   63:
#   64: def get_chunks(data, batch_size):
#   65:     count_bags = len(data)
#   66:     for indx in range(0, count_bags, batch_size):
#   67:         yield data[indx:min(indx + batch_size, count_bags)]
#   68:
#   69: def get_batches(batches):
#   70:     while True:
#   71:         for batch in batches:
#   72:             yield ({'bert_input': np.array(batch[0], dtype='float32'),
#   73:                     'alias': np.array(batch[1], dtype='int32'),
#   74:                     'subj': np.array(batch[2], dtype='int32'),
#   75:                     'obj': np.array(batch[3], dtype='int32')},
#   76:                    {'output': np.array(batch[4], dtype='int32')})
#   77:
#   78: def create_batches(data, batch_size=64):
#   79:     batches = []
#   80:     for chunk in get_chunks(data, batch_size):
#   81:         batch = ddict(list)
#   82:         num = 0
#   83:
#   84:         bert = []
#   85:         alias = []
#   86:         subj = []
#   87:         obj = []
#   88:         out = []
#   89:         for i, bag in enumerate(chunk):
#   90:             bert.append(bag[0])
#   91:             alias.append(bag[1])
#   92:             subj.append(bag[2])
#   93:             obj.append(bag[3])
#   94:             out.append(bag[4])
#   95:         batches.append([bert, alias, subj, obj, out])
#   96:
#   97:     return batches, len(batches)
#   98:
#   99:
# >>> Data
#   1: path2datafile, models_dir, model_name = '/content/drive/My Drive/Doutorado/[DL] Projeto/data/gids_bert_processed-test.pkl', '/content/drive/My Drive/Doutorado/[DL] Projeto/models/', 'best_model-12-12'
#   2:
#   3: batch_size = 512
#   4: type_dim = 150
#   5: alias_dim = 150
#   6: embedding_dim = 768
#   7: L2 = 0.001
#   8: regularizer = tf.keras.regularizers.l2(l=0.5 * (L2))
#   9:
#  10: data = pickle.load(open(path2datafile, 'rb'))
#  11:
#  12: voc2id      = data['voc2id']
#  13: id2voc      = data['id2voc']
#  14: type2id     = data['type2id']
#  15: type_count  = len(data['type2id'])
#  16: num_class   = len(data['rel2id'])
#  17: max_pos = data['max_pos']
#  18:
#  19: print("getData Train")
#  20: train, train_bags, alias_count = getData(data['train'])
#  21:
#  22: print("getData Validation")
#  23: validation, test_bags, alias_count = getData(data['dev'])
#  24:
#  25: print("getData Test")
#  26: test, dev_bags, alias_count = getData(data['test'])
#  27:
#  28:
#  29:
#  30:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:
#    4:     # embed input
#    5:     embed_input = tf.keras.Input(shape=(None, embedding_dim,), name="bert_input", dtype='float32')
#    6:
#    7:     # embed alias
#    8:     alias_input = tf.keras.Input(shape=(None, None,), name="alias", dtype='int32')
#    9:     embed_alias = tf.keras.layers.Embedding(input_dim=alias_count,
#   10:                                             output_dim=alias_dim, trainable=True,
#   11:                                             embeddings_initializer=tf.keras.initializers.VarianceScaling(
#   12:                                                 scale=1.0, mode="fan_avg", distribution="uniform"),
#   13:                                             embeddings_regularizer=regularizer, name='alias_embed')(alias_input)
#   14:
#   15:     alias_av = tf.math.reduce_sum(input_tensor=embed_alias, axis=2, keepdims=False, name='alias_mean') / tf.cast(tf.shape(embed_alias)[1], tf.float32)
#   16:
#   17:     # sentence representations
#   18:     sent_reps = tf.keras.layers.concatenate([embed_input, alias_av], axis=2, name='bert_alias_concat')
#   19:
#   20:
#   21:     # Input subj-obj types
#   22:     subj_input = tf.keras.layers.Input(shape=(None,), name="subj", dtype='int32')
#   23:     obj_input = tf.keras.layers.Input(shape=(None,), name="obj", dtype='int32')
#   24:
#   25:     # embed subj-obj types
#   26:     embed_type = tf.keras.layers.Embedding(input_dim=type_count, output_dim=type_dim,
#   27:                                            embeddings_regularizer=regularizer,
#   28:                                            embeddings_initializer=tf.compat.v1.keras.initializers.VarianceScaling(
#   29:                                                scale=1.0, mode="fan_avg", distribution="uniform"), name='type_embed')
#   30:     subj_embed = embed_type(subj_input)
#   31:     obj_embed = embed_type(obj_input)
#   32:
#   33:     # average of types representations
#   34:     subj_type_av = tf.math.reduce_mean(input_tensor=subj_embed, axis=1, name='subj_mean')
#   35:     obj_type_av = tf.math.reduce_mean(input_tensor=obj_embed, axis=1, name='obj_mean')
#   36:
#   37:     # concatenate subject and object to one single representation
#   38:     concat_type = tf.keras.layers.concatenate([subj_type_av, obj_type_av], axis=1, name='type_concat')
#   39:
#   40:     # weights for querying attention layer
#   41:     # samples are drawn from a uniform distribution within [-limit, limit], with limit = sqrt(3 * scale / n)
#   42:     sent_atten_q = tf.keras.initializers.VarianceScaling(scale=1.0,
#   43:                                                          mode="fan_avg",
#   44:                                                          distribution="uniform")(shape=(1, 1, alias_dim+embedding_dim))  # alias_dim+
#   45:
#   46:     # Bag Attention sentence level
#   47:     bag_attention = tf.keras.layers.Attention(name='attention')([sent_atten_q, sent_reps])
#   48:
#   49:     mean_bag_attention = tf.math.reduce_mean(bag_attention, axis=1)
#   50:
#   51:     bag_reps = tf.keras.layers.concatenate([mean_bag_attention, concat_type], axis=1, name='bag_rep_type_concat')
#   52:
#   53:     # fully connected
#   54:     fc1 = tf.keras.layers.Dense(units=space['units'],
#   55:                                 activation="relu",
#   56:                                 kernel_regularizer=regularizer, name='fully1')(bag_reps)
#   57:
#   58:     drop1 = tf.keras.layers.Dropout(rate=space['rate'], name='drop1')(fc1)
#   59:
#   60:     fc2 = tf.keras.layers.Dense(units=space['units_1'],
#   61:                                 activation="relu",
#   62:                                 kernel_regularizer=regularizer, name='fully2')(drop1)
#   63:
#   64:     drop = tf.keras.layers.Dropout(rate=space['rate_1'], name='drop2')(fc2)
#   65:
#   66:     # output layer
#   67:     label = tf.keras.layers.Dense(num_class, activation='softmax', kernel_regularizer=regularizer, name='output')(drop)
#   68:
#   69:     model = tf.keras.Model([embed_input, alias_input, subj_input, obj_input], label)
#   70:
#   71:     print(model.summary())
#   72:
#   73:     optim = tf.keras.optimizers.SGD(lr=space['rate_2'], name='SGD')
#   74:
#   75:     model.compile(loss=tf.keras.losses.sparse_categorical_crossentropy,
#   76:                   optimizer=optim,
#   77:                   metrics=['accuracy'])
#   78:
#   79:     train_batches, train_batches_len = create_batches(train, batch_size)
#   80:     val_batches, val_batches_len = create_batches(validation, batch_size)
#   81:     test_batches, test_batches_len = create_batches(test, batch_size)
#   82:
#   83:     checkpointer = tf.keras.callbacks.ModelCheckpoint(filepath=models_dir+ model_name + "es_best.h5", verbose=1,
#   84:                                    save_best_only=True, save_weights_only=True)
#   85:     earlystopper = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=40, verbose=1)
#   86:
#   87:     history = model.fit_generator(get_batches(train_batches), steps_per_epoch=train_batches_len,
#   88:                         epochs=500, verbose=2, validation_steps=val_batches_len,
#   89:                         validation_data=get_batches(val_batches), callbacks=[checkpointer, earlystopper])
#   90:
#   91:     score, acc = model.evaluate_generator(generator=get_batches(test_batches),
#   92:                                           steps=test_batches_len, verbose=0)
#   93:     print('Test accuracy:', acc)
#   94:
#   95:     return {'loss': -acc, 'status': STATUS_OK, 'model': model,
#   96:             'history.val_loss':history.history['val_loss'],
#   97:             'history.val_acc': history.history['val_accuracy'],
#   98:             'history.loss': history.history['loss'],
#   99:             'history.acc': history.history['accuracy']}
#  100:
# getData Train
# getData Validation
# getData Test
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]WARNING:tensorflow:Large dropout rate: 0.610876 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.73717 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# alias (InputLayer)              [(None, None, None)] 0
# __________________________________________________________________________________________________
# alias_embed (Embedding)         (None, None, None, 1 750         alias[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape_1 (TensorFlow [(4,)]               0           alias_embed[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_1 (Te [()]                 0           tf_op_layer_Shape_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_alias_mean_1 (Tenso [(None, None, 150)]  0           alias_embed[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_1 (TensorFlowO [()]                 0           tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# bert_input (InputLayer)         [(None, None, 768)]  0
# __________________________________________________________________________________________________
# tf_op_layer_truediv_1 (TensorFl [(None, None, 150)]  0           tf_op_layer_alias_mean_1[0][0]
#                                                                  tf_op_layer_Cast_1[0][0]
# __________________________________________________________________________________________________
# bert_alias_concat (Concatenate) (None, None, 918)    0           bert_input[0][0]
#                                                                  tf_op_layer_truediv_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_MatMul_2 (TensorFlo [(None, 1, None)]    0           bert_alias_concat[0][0]
# __________________________________________________________________________________________________
# subj (InputLayer)               [(None, None)]       0
# __________________________________________________________________________________________________
# obj (InputLayer)                [(None, None)]       0
# __________________________________________________________________________________________________
# tf_op_layer_Softmax_1 (TensorFl [(None, 1, None)]    0           tf_op_layer_MatMul_2[0][0]
# __________________________________________________________________________________________________
# type_embed (Embedding)          (None, None, 150)    3750        subj[0][0]
#                                                                  obj[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_MatMul_3 (TensorFlo [(None, 1, 918)]     0           tf_op_layer_Softmax_1[0][0]
#                                                                  bert_alias_concat[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_subj_mean_1 (Tensor [(None, 150)]        0           type_embed[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_obj_mean_1 (TensorF [(None, 150)]        0           type_embed[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_1 (TensorFlowO [(None, 918)]        0           tf_op_layer_MatMul_3[0][0]
# __________________________________________________________________________________________________
# type_concat (Concatenate)       (None, 300)          0           tf_op_layer_subj_mean_1[0][0]
#                                                                  tf_op_layer_obj_mean_1[0][0]
# __________________________________________________________________________________________________
# bag_rep_type_concat (Concatenat (None, 1218)         0           tf_op_layer_Mean_1[0][0]
#                                                                  type_concat[0][0]
# __________________________________________________________________________________________________
# fully1 (Dense)                  (None, 96)           117024      bag_rep_type_concat[0][0]
# __________________________________________________________________________________________________
# drop1 (Dropout)                 (None, 96)           0           fully1[0][0]
# __________________________________________________________________________________________________
# fully2 (Dense)                  (None, 24)           2328        drop1[0][0]
# __________________________________________________________________________________________________
# drop2 (Dropout)                 (None, 24)           0           fully2[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 5)            125         drop2[0][0]
# ==================================================================================================
# Total params: 123,977
# Trainable params: 123,977
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/500
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]WARNING:tensorflow:Large dropout rate: 0.610876 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
#
# Epoch 00001: val_loss improved from inf to 1.51085, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 3s - loss: 1.6069 - accuracy: 0.3526 - val_loss: 1.5108 - val_accuracy: 0.3784
#
# Epoch 2/500
#
# Epoch 00002: val_loss improved from 1.51085 to 1.45720, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 1.5126 - accuracy: 0.3772 - val_loss: 1.4572 - val_accuracy: 0.3784
#
# Epoch 3/500
#
# Epoch 00003: val_loss improved from 1.45720 to 1.39789, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 1.4614 - accuracy: 0.3888 - val_loss: 1.3979 - val_accuracy: 0.3784
#
# Epoch 4/500
#
# Epoch 00004: val_loss improved from 1.39789 to 1.35547, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 1.4368 - accuracy: 0.3920 - val_loss: 1.3555 - val_accuracy: 0.4727
#
# Epoch 5/500
#
# Epoch 00005: val_loss improved from 1.35547 to 1.23312, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 1.4069 - accuracy: 0.3915 - val_loss: 1.2331 - val_accuracy: 0.3793
#
# Epoch 6/500
#
# Epoch 00006: val_loss did not improve from 1.23312
# 13/13 - 2s - loss: 1.3757 - accuracy: 0.3994 - val_loss: 1.2674 - val_accuracy: 0.4052
#
# Epoch 7/500
#
# Epoch 00007: val_loss improved from 1.23312 to 1.07761, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 1.3207 - accuracy: 0.4269 - val_loss: 1.0776 - val_accuracy: 0.6512
#
# Epoch 8/500
#
# Epoch 00008: val_loss did not improve from 1.07761
# 13/13 - 2s - loss: 1.3224 - accuracy: 0.4254 - val_loss: 1.0865 - val_accuracy: 0.6013
#
# Epoch 9/500
#
# Epoch 00009: val_loss improved from 1.07761 to 1.02005, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 1.2234 - accuracy: 0.4676 - val_loss: 1.0200 - val_accuracy: 0.6846
#
# Epoch 10/500
#
# Epoch 00010: val_loss improved from 1.02005 to 0.98747, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 1.1786 - accuracy: 0.4754 - val_loss: 0.9875 - val_accuracy: 0.6161
#
# Epoch 11/500
#
# Epoch 00011: val_loss improved from 0.98747 to 0.97360, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 1.1581 - accuracy: 0.4955 - val_loss: 0.9736 - val_accuracy: 0.6753
#
# Epoch 12/500
#
# Epoch 00012: val_loss improved from 0.97360 to 0.95620, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 1.1461 - accuracy: 0.4953 - val_loss: 0.9562 - val_accuracy: 0.6503
#
# Epoch 13/500
#
# Epoch 00013: val_loss did not improve from 0.95620
# 13/13 - 2s - loss: 1.2377 - accuracy: 0.4567 - val_loss: 0.9884 - val_accuracy: 0.6512
#
# Epoch 14/500
#
# Epoch 00014: val_loss improved from 0.95620 to 0.93220, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 1.1347 - accuracy: 0.5045 - val_loss: 0.9322 - val_accuracy: 0.6707
#
# Epoch 15/500
#
# Epoch 00015: val_loss improved from 0.93220 to 0.90575, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 1.0980 - accuracy: 0.5193 - val_loss: 0.9058 - val_accuracy: 0.7197
#
# Epoch 16/500
#
# Epoch 00016: val_loss improved from 0.90575 to 0.89201, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 1.0814 - accuracy: 0.5276 - val_loss: 0.8920 - val_accuracy: 0.7031
#
# Epoch 17/500
#
# Epoch 00017: val_loss did not improve from 0.89201
# 13/13 - 2s - loss: 1.0697 - accuracy: 0.5281 - val_loss: 0.8974 - val_accuracy: 0.6596
#
# Epoch 18/500
#
# Epoch 00018: val_loss did not improve from 0.89201
# 13/13 - 2s - loss: 1.0686 - accuracy: 0.5310 - val_loss: 0.8987 - val_accuracy: 0.7123
#
# Epoch 19/500
#
# Epoch 00019: val_loss improved from 0.89201 to 0.88988, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 1.0438 - accuracy: 0.5507 - val_loss: 0.8899 - val_accuracy: 0.6670
#
# Epoch 20/500
#
# Epoch 00020: val_loss improved from 0.88988 to 0.86100, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 1.0422 - accuracy: 0.5558 - val_loss: 0.8610 - val_accuracy: 0.7095
#
# Epoch 21/500
#
# Epoch 00021: val_loss did not improve from 0.86100
# 13/13 - 2s - loss: 1.0368 - accuracy: 0.5507 - val_loss: 0.8653 - val_accuracy: 0.7105
#
# Epoch 22/500
#
# Epoch 00022: val_loss improved from 0.86100 to 0.85050, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 1.0190 - accuracy: 0.5721 - val_loss: 0.8505 - val_accuracy: 0.6735
#
# Epoch 23/500
#
# Epoch 00023: val_loss improved from 0.85050 to 0.84375, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 1.0404 - accuracy: 0.5557 - val_loss: 0.8438 - val_accuracy: 0.7253
#
# Epoch 24/500
#
# Epoch 00024: val_loss improved from 0.84375 to 0.83393, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 1.0038 - accuracy: 0.5814 - val_loss: 0.8339 - val_accuracy: 0.6975
#
# Epoch 25/500
#
# Epoch 00025: val_loss improved from 0.83393 to 0.83152, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 1.0032 - accuracy: 0.5757 - val_loss: 0.8315 - val_accuracy: 0.7308
#
# Epoch 26/500
#
# Epoch 00026: val_loss improved from 0.83152 to 0.82064, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 1.0206 - accuracy: 0.5740 - val_loss: 0.8206 - val_accuracy: 0.7169
#
# Epoch 27/500
#
# Epoch 00027: val_loss improved from 0.82064 to 0.80470, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.9814 - accuracy: 0.5988 - val_loss: 0.8047 - val_accuracy: 0.7151
#
# Epoch 28/500
#
# Epoch 00028: val_loss improved from 0.80470 to 0.79298, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.9766 - accuracy: 0.5962 - val_loss: 0.7930 - val_accuracy: 0.6994
#
# Epoch 29/500
#
# Epoch 00029: val_loss did not improve from 0.79298
# 13/13 - 2s - loss: 1.0322 - accuracy: 0.5661 - val_loss: 0.8068 - val_accuracy: 0.7206
#
# Epoch 30/500
#
# Epoch 00030: val_loss improved from 0.79298 to 0.78968, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.9627 - accuracy: 0.6094 - val_loss: 0.7897 - val_accuracy: 0.7142
#
# Epoch 31/500
#
# Epoch 00031: val_loss improved from 0.78968 to 0.78582, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.9616 - accuracy: 0.6129 - val_loss: 0.7858 - val_accuracy: 0.7179
#
# Epoch 32/500
#
# Epoch 00032: val_loss did not improve from 0.78582
# 13/13 - 2s - loss: 0.9541 - accuracy: 0.6088 - val_loss: 0.7981 - val_accuracy: 0.7225
#
# Epoch 33/500
#
# Epoch 00033: val_loss improved from 0.78582 to 0.77763, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.9475 - accuracy: 0.6169 - val_loss: 0.7776 - val_accuracy: 0.7197
#
# Epoch 34/500
#
# Epoch 00034: val_loss improved from 0.77763 to 0.76533, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.9568 - accuracy: 0.6172 - val_loss: 0.7653 - val_accuracy: 0.7123
#
# Epoch 35/500
#
# Epoch 00035: val_loss did not improve from 0.76533
# 13/13 - 2s - loss: 0.9371 - accuracy: 0.6222 - val_loss: 0.7663 - val_accuracy: 0.7105
#
# Epoch 36/500
#
# Epoch 00036: val_loss did not improve from 0.76533
# 13/13 - 2s - loss: 0.9294 - accuracy: 0.6297 - val_loss: 0.8045 - val_accuracy: 0.7105
#
# Epoch 37/500
#
# Epoch 00037: val_loss did not improve from 0.76533
# 13/13 - 2s - loss: 0.9276 - accuracy: 0.6302 - val_loss: 0.7656 - val_accuracy: 0.7345
#
# Epoch 38/500
#
# Epoch 00038: val_loss improved from 0.76533 to 0.74973, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.9228 - accuracy: 0.6316 - val_loss: 0.7497 - val_accuracy: 0.7225
#
# Epoch 39/500
#
# Epoch 00039: val_loss did not improve from 0.74973
# 13/13 - 2s - loss: 0.9310 - accuracy: 0.6313 - val_loss: 0.7845 - val_accuracy: 0.6994
#
# Epoch 40/500
#
# Epoch 00040: val_loss improved from 0.74973 to 0.74757, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.9755 - accuracy: 0.6125 - val_loss: 0.7476 - val_accuracy: 0.7188
#
# Epoch 41/500
#
# Epoch 00041: val_loss improved from 0.74757 to 0.74603, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.9120 - accuracy: 0.6390 - val_loss: 0.7460 - val_accuracy: 0.7114
#
# Epoch 42/500
#
# Epoch 00042: val_loss improved from 0.74603 to 0.73310, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.9157 - accuracy: 0.6419 - val_loss: 0.7331 - val_accuracy: 0.7225
#
# Epoch 43/500
#
# Epoch 00043: val_loss did not improve from 0.73310
# 13/13 - 2s - loss: 0.9207 - accuracy: 0.6357 - val_loss: 0.7705 - val_accuracy: 0.7271
#
# Epoch 44/500
#
# Epoch 00044: val_loss did not improve from 0.73310
# 13/13 - 2s - loss: 0.9095 - accuracy: 0.6380 - val_loss: 0.7964 - val_accuracy: 0.7058
#
# Epoch 45/500
#
# Epoch 00045: val_loss did not improve from 0.73310
# 13/13 - 2s - loss: 0.9067 - accuracy: 0.6393 - val_loss: 0.7337 - val_accuracy: 0.7225
#
# Epoch 46/500
#
# Epoch 00046: val_loss did not improve from 0.73310
# 13/13 - 2s - loss: 0.9106 - accuracy: 0.6403 - val_loss: 0.7870 - val_accuracy: 0.6994
#
# Epoch 47/500
#
# Epoch 00047: val_loss did not improve from 0.73310
# 13/13 - 2s - loss: 0.9372 - accuracy: 0.6357 - val_loss: 0.9403 - val_accuracy: 0.6309
#
# Epoch 48/500
#
# Epoch 00048: val_loss did not improve from 0.73310
# 13/13 - 2s - loss: 0.9120 - accuracy: 0.6442 - val_loss: 0.7551 - val_accuracy: 0.7179
#
# Epoch 49/500
#
# Epoch 00049: val_loss did not improve from 0.73310
# 13/13 - 2s - loss: 0.9106 - accuracy: 0.6462 - val_loss: 0.7428 - val_accuracy: 0.7225
#
# Epoch 50/500
#
# Epoch 00050: val_loss did not improve from 0.73310
# 13/13 - 2s - loss: 0.8984 - accuracy: 0.6490 - val_loss: 0.7803 - val_accuracy: 0.7105
#
# Epoch 51/500
#
# Epoch 00051: val_loss improved from 0.73310 to 0.72774, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.8869 - accuracy: 0.6540 - val_loss: 0.7277 - val_accuracy: 0.7160
#
# Epoch 52/500
#
# Epoch 00052: val_loss did not improve from 0.72774
# 13/13 - 2s - loss: 0.8733 - accuracy: 0.6653 - val_loss: 0.7318 - val_accuracy: 0.7123
#
# Epoch 53/500
#
# Epoch 00053: val_loss improved from 0.72774 to 0.71570, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.8955 - accuracy: 0.6491 - val_loss: 0.7157 - val_accuracy: 0.7197
#
# Epoch 54/500
#
# Epoch 00054: val_loss did not improve from 0.71570
# 13/13 - 2s - loss: 0.8918 - accuracy: 0.6487 - val_loss: 0.7564 - val_accuracy: 0.7188
#
# Epoch 55/500
#
# Epoch 00055: val_loss did not improve from 0.71570
# 13/13 - 2s - loss: 0.8950 - accuracy: 0.6516 - val_loss: 0.7167 - val_accuracy: 0.7206
#
# Epoch 56/500
#
# Epoch 00056: val_loss improved from 0.71570 to 0.71402, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.8715 - accuracy: 0.6590 - val_loss: 0.7140 - val_accuracy: 0.7169
#
# Epoch 57/500
#
# Epoch 00057: val_loss improved from 0.71402 to 0.71115, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.8750 - accuracy: 0.6645 - val_loss: 0.7112 - val_accuracy: 0.7364
#
# Epoch 58/500
#
# Epoch 00058: val_loss improved from 0.71115 to 0.71106, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.8910 - accuracy: 0.6496 - val_loss: 0.7111 - val_accuracy: 0.7290
#
# Epoch 59/500
#
# Epoch 00059: val_loss did not improve from 0.71106
# 13/13 - 2s - loss: 0.8864 - accuracy: 0.6577 - val_loss: 0.7414 - val_accuracy: 0.7142
#
# Epoch 60/500
#
# Epoch 00060: val_loss improved from 0.71106 to 0.69673, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.8762 - accuracy: 0.6640 - val_loss: 0.6967 - val_accuracy: 0.7271
#
# Epoch 61/500
#
# Epoch 00061: val_loss did not improve from 0.69673
# 13/13 - 2s - loss: 0.8695 - accuracy: 0.6667 - val_loss: 0.7227 - val_accuracy: 0.7169
#
# Epoch 62/500
#
# Epoch 00062: val_loss did not improve from 0.69673
# 13/13 - 2s - loss: 1.0219 - accuracy: 0.5957 - val_loss: 0.7419 - val_accuracy: 0.7225
#
# Epoch 63/500
#
# Epoch 00063: val_loss did not improve from 0.69673
# 13/13 - 2s - loss: 0.8936 - accuracy: 0.6605 - val_loss: 0.8288 - val_accuracy: 0.6753
#
# Epoch 64/500
#
# Epoch 00064: val_loss did not improve from 0.69673
# 13/13 - 2s - loss: 0.8936 - accuracy: 0.6516 - val_loss: 0.6994 - val_accuracy: 0.7280
#
# Epoch 65/500
#
# Epoch 00065: val_loss did not improve from 0.69673
# 13/13 - 2s - loss: 0.8714 - accuracy: 0.6634 - val_loss: 0.7107 - val_accuracy: 0.7308
#
# Epoch 66/500
#
# Epoch 00066: val_loss improved from 0.69673 to 0.69657, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.8711 - accuracy: 0.6645 - val_loss: 0.6966 - val_accuracy: 0.7401
#
# Epoch 67/500
#
# Epoch 00067: val_loss did not improve from 0.69657
# 13/13 - 2s - loss: 0.8621 - accuracy: 0.6687 - val_loss: 0.6971 - val_accuracy: 0.7345
#
# Epoch 68/500
#
# Epoch 00068: val_loss did not improve from 0.69657
# 13/13 - 2s - loss: 0.8758 - accuracy: 0.6622 - val_loss: 0.7274 - val_accuracy: 0.7206
#
# Epoch 69/500
#
# Epoch 00069: val_loss did not improve from 0.69657
# 13/13 - 2s - loss: 0.8796 - accuracy: 0.6633 - val_loss: 0.7142 - val_accuracy: 0.7290
#
# Epoch 70/500
#
# Epoch 00070: val_loss did not improve from 0.69657
# 13/13 - 2s - loss: 0.8609 - accuracy: 0.6673 - val_loss: 0.7428 - val_accuracy: 0.7105
#
# Epoch 71/500
#
# Epoch 00071: val_loss did not improve from 0.69657
# 13/13 - 2s - loss: 0.8903 - accuracy: 0.6490 - val_loss: 0.7110 - val_accuracy: 0.7299
#
# Epoch 72/500
#
# Epoch 00072: val_loss did not improve from 0.69657
# 13/13 - 2s - loss: 0.8617 - accuracy: 0.6711 - val_loss: 0.7002 - val_accuracy: 0.7317
#
# Epoch 73/500
#
# Epoch 00073: val_loss did not improve from 0.69657
# 13/13 - 2s - loss: 0.8596 - accuracy: 0.6748 - val_loss: 0.7065 - val_accuracy: 0.7142
#
# Epoch 74/500
#
# Epoch 00074: val_loss improved from 0.69657 to 0.69083, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.8603 - accuracy: 0.6664 - val_loss: 0.6908 - val_accuracy: 0.7253
#
# Epoch 75/500
#
# Epoch 00075: val_loss did not improve from 0.69083
# 13/13 - 2s - loss: 0.8417 - accuracy: 0.6782 - val_loss: 0.7062 - val_accuracy: 0.7132
#
# Epoch 76/500
#
# Epoch 00076: val_loss improved from 0.69083 to 0.68697, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.8678 - accuracy: 0.6645 - val_loss: 0.6870 - val_accuracy: 0.7317
#
# Epoch 77/500
#
# Epoch 00077: val_loss did not improve from 0.68697
# 13/13 - 2s - loss: 0.8445 - accuracy: 0.6790 - val_loss: 0.7274 - val_accuracy: 0.6929
#
# Epoch 78/500
#
# Epoch 00078: val_loss did not improve from 0.68697
# 13/13 - 2s - loss: 0.8547 - accuracy: 0.6681 - val_loss: 0.7029 - val_accuracy: 0.7345
#
# Epoch 79/500
#
# Epoch 00079: val_loss did not improve from 0.68697
# 13/13 - 2s - loss: 0.8428 - accuracy: 0.6702 - val_loss: 0.7546 - val_accuracy: 0.7095
#
# Epoch 80/500
#
# Epoch 00080: val_loss did not improve from 0.68697
# 13/13 - 2s - loss: 0.8453 - accuracy: 0.6681 - val_loss: 0.7685 - val_accuracy: 0.6920
#
# Epoch 81/500
#
# Epoch 00081: val_loss did not improve from 0.68697
# 13/13 - 2s - loss: 0.8329 - accuracy: 0.6842 - val_loss: 0.7146 - val_accuracy: 0.7169
#
# Epoch 82/500
#
# Epoch 00082: val_loss did not improve from 0.68697
# 13/13 - 2s - loss: 1.0207 - accuracy: 0.6083 - val_loss: 0.7176 - val_accuracy: 0.7336
#
# Epoch 83/500
#
# Epoch 00083: val_loss did not improve from 0.68697
# 13/13 - 2s - loss: 0.8712 - accuracy: 0.6671 - val_loss: 0.6953 - val_accuracy: 0.7262
#
# Epoch 84/500
#
# Epoch 00084: val_loss did not improve from 0.68697
# 13/13 - 2s - loss: 0.8651 - accuracy: 0.6688 - val_loss: 0.6947 - val_accuracy: 0.7280
#
# Epoch 85/500
#
# Epoch 00085: val_loss did not improve from 0.68697
# 13/13 - 2s - loss: 0.8465 - accuracy: 0.6714 - val_loss: 0.7024 - val_accuracy: 0.7336
#
# Epoch 86/500
#
# Epoch 00086: val_loss did not improve from 0.68697
# 13/13 - 2s - loss: 0.8495 - accuracy: 0.6768 - val_loss: 0.6950 - val_accuracy: 0.7373
#
# Epoch 87/500
#
# Epoch 00087: val_loss did not improve from 0.68697
# 13/13 - 2s - loss: 0.8464 - accuracy: 0.6814 - val_loss: 0.7052 - val_accuracy: 0.7262
#
# Epoch 88/500
#
# Epoch 00088: val_loss did not improve from 0.68697
# 13/13 - 2s - loss: 0.8442 - accuracy: 0.6787 - val_loss: 0.6894 - val_accuracy: 0.7280
#
# Epoch 89/500
#
# Epoch 00089: val_loss did not improve from 0.68697
# 13/13 - 2s - loss: 0.8660 - accuracy: 0.6616 - val_loss: 0.6988 - val_accuracy: 0.7243
#
# Epoch 90/500
#
# Epoch 00090: val_loss did not improve from 0.68697
# 13/13 - 2s - loss: 0.8628 - accuracy: 0.6684 - val_loss: 0.7110 - val_accuracy: 0.7253
#
# Epoch 91/500
#
# Epoch 00091: val_loss did not improve from 0.68697
# 13/13 - 2s - loss: 0.8447 - accuracy: 0.6702 - val_loss: 0.6920 - val_accuracy: 0.7206
#
# Epoch 92/500
#
# Epoch 00092: val_loss improved from 0.68697 to 0.67660, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.8507 - accuracy: 0.6716 - val_loss: 0.6766 - val_accuracy: 0.7290
#
# Epoch 93/500
#
# Epoch 00093: val_loss did not improve from 0.67660
# 13/13 - 2s - loss: 0.8241 - accuracy: 0.6808 - val_loss: 0.6936 - val_accuracy: 0.7327
#
# Epoch 94/500
#
# Epoch 00094: val_loss did not improve from 0.67660
# 13/13 - 2s - loss: 0.8553 - accuracy: 0.6716 - val_loss: 0.7350 - val_accuracy: 0.6725
#
# Epoch 95/500
#
# Epoch 00095: val_loss did not improve from 0.67660
# 13/13 - 2s - loss: 0.8437 - accuracy: 0.6730 - val_loss: 0.7080 - val_accuracy: 0.7271
#
# Epoch 96/500
#
# Epoch 00096: val_loss did not improve from 0.67660
# 13/13 - 2s - loss: 0.9020 - accuracy: 0.6439 - val_loss: 0.6967 - val_accuracy: 0.7290
#
# Epoch 97/500
#
# Epoch 00097: val_loss did not improve from 0.67660
# 13/13 - 2s - loss: 0.8494 - accuracy: 0.6719 - val_loss: 0.6838 - val_accuracy: 0.7216
#
# Epoch 98/500
#
# Epoch 00098: val_loss did not improve from 0.67660
# 13/13 - 2s - loss: 0.8308 - accuracy: 0.6794 - val_loss: 0.6940 - val_accuracy: 0.7216
#
# Epoch 99/500
#
# Epoch 00099: val_loss did not improve from 0.67660
# 13/13 - 2s - loss: 0.8316 - accuracy: 0.6773 - val_loss: 0.6936 - val_accuracy: 0.7179
#
# Epoch 100/500
#
# Epoch 00100: val_loss did not improve from 0.67660
# 13/13 - 2s - loss: 0.8152 - accuracy: 0.6827 - val_loss: 0.6885 - val_accuracy: 0.7299
#
# Epoch 101/500
#
# Epoch 00101: val_loss did not improve from 0.67660
# 13/13 - 2s - loss: 0.8431 - accuracy: 0.6773 - val_loss: 0.7396 - val_accuracy: 0.7095
#
# Epoch 102/500
#
# Epoch 00102: val_loss did not improve from 0.67660
# 13/13 - 2s - loss: 0.8362 - accuracy: 0.6751 - val_loss: 0.7316 - val_accuracy: 0.7253
#
# Epoch 103/500
#
# Epoch 00103: val_loss did not improve from 0.67660
# 13/13 - 2s - loss: 0.8288 - accuracy: 0.6824 - val_loss: 0.7119 - val_accuracy: 0.7021
#
# Epoch 104/500
#
# Epoch 00104: val_loss did not improve from 0.67660
# 13/13 - 2s - loss: 0.8267 - accuracy: 0.6774 - val_loss: 0.7432 - val_accuracy: 0.7068
#
# Epoch 105/500
#
# Epoch 00105: val_loss did not improve from 0.67660
# 13/13 - 2s - loss: 0.8264 - accuracy: 0.6796 - val_loss: 0.7703 - val_accuracy: 0.7216
#
# Epoch 106/500
#
# Epoch 00106: val_loss did not improve from 0.67660
# 13/13 - 2s - loss: 0.8302 - accuracy: 0.6751 - val_loss: 0.7296 - val_accuracy: 0.7021
#
# Epoch 107/500
#
# Epoch 00107: val_loss did not improve from 0.67660
# 13/13 - 2s - loss: 0.8386 - accuracy: 0.6737 - val_loss: 0.6942 - val_accuracy: 0.7308
#
# Epoch 108/500
#
# Epoch 00108: val_loss did not improve from 0.67660
# 13/13 - 2s - loss: 0.8147 - accuracy: 0.6808 - val_loss: 0.6962 - val_accuracy: 0.7095
#
# Epoch 109/500
#
# Epoch 00109: val_loss did not improve from 0.67660
# 13/13 - 2s - loss: 0.8247 - accuracy: 0.6805 - val_loss: 0.7598 - val_accuracy: 0.7086
#
# Epoch 110/500
#
# Epoch 00110: val_loss did not improve from 0.67660
# 13/13 - 2s - loss: 0.8380 - accuracy: 0.6699 - val_loss: 0.6852 - val_accuracy: 0.7299
#
# Epoch 111/500
#
# Epoch 00111: val_loss did not improve from 0.67660
# 13/13 - 2s - loss: 0.8451 - accuracy: 0.6693 - val_loss: 0.6893 - val_accuracy: 0.7179
#
# Epoch 112/500
#
# Epoch 00112: val_loss improved from 0.67660 to 0.66327, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.8137 - accuracy: 0.6847 - val_loss: 0.6633 - val_accuracy: 0.7401
#
# Epoch 113/500
#
# Epoch 00113: val_loss did not improve from 0.66327
# 13/13 - 2s - loss: 0.8223 - accuracy: 0.6796 - val_loss: 0.7465 - val_accuracy: 0.7188
#
# Epoch 114/500
#
# Epoch 00114: val_loss did not improve from 0.66327
# 13/13 - 2s - loss: 0.8176 - accuracy: 0.6825 - val_loss: 0.6842 - val_accuracy: 0.7308
#
# Epoch 115/500
#
# Epoch 00115: val_loss did not improve from 0.66327
# 13/13 - 2s - loss: 0.8441 - accuracy: 0.6708 - val_loss: 0.7751 - val_accuracy: 0.7216
#
# Epoch 116/500
#
# Epoch 00116: val_loss did not improve from 0.66327
# 13/13 - 2s - loss: 0.8401 - accuracy: 0.6693 - val_loss: 0.6715 - val_accuracy: 0.7391
#
# Epoch 117/500
#
# Epoch 00117: val_loss did not improve from 0.66327
# 13/13 - 2s - loss: 0.8259 - accuracy: 0.6821 - val_loss: 0.6949 - val_accuracy: 0.7327
#
# Epoch 118/500
#
# Epoch 00118: val_loss did not improve from 0.66327
# 13/13 - 2s - loss: 0.8992 - accuracy: 0.6467 - val_loss: 0.6934 - val_accuracy: 0.7354
#
# Epoch 119/500
#
# Epoch 00119: val_loss did not improve from 0.66327
# 13/13 - 2s - loss: 0.8187 - accuracy: 0.6850 - val_loss: 0.6923 - val_accuracy: 0.7391
#
# Epoch 120/500
#
# Epoch 00120: val_loss did not improve from 0.66327
# 13/13 - 2s - loss: 0.8232 - accuracy: 0.6736 - val_loss: 0.6963 - val_accuracy: 0.7308
#
# Epoch 121/500
#
# Epoch 00121: val_loss did not improve from 0.66327
# 13/13 - 2s - loss: 0.8204 - accuracy: 0.6833 - val_loss: 0.6923 - val_accuracy: 0.7280
#
# Epoch 122/500
#
# Epoch 00122: val_loss did not improve from 0.66327
# 13/13 - 2s - loss: 0.8258 - accuracy: 0.6782 - val_loss: 0.6662 - val_accuracy: 0.7512
#
# Epoch 123/500
#
# Epoch 00123: val_loss did not improve from 0.66327
# 13/13 - 2s - loss: 0.8181 - accuracy: 0.6831 - val_loss: 0.6824 - val_accuracy: 0.7475
#
# Epoch 124/500
#
# Epoch 00124: val_loss did not improve from 0.66327
# 13/13 - 2s - loss: 0.8213 - accuracy: 0.6796 - val_loss: 0.6657 - val_accuracy: 0.7391
#
# Epoch 125/500
#
# Epoch 00125: val_loss did not improve from 0.66327
# 13/13 - 2s - loss: 0.8169 - accuracy: 0.6861 - val_loss: 0.6950 - val_accuracy: 0.7234
#
# Epoch 126/500
#
# Epoch 00126: val_loss did not improve from 0.66327
# 13/13 - 2s - loss: 0.8134 - accuracy: 0.6859 - val_loss: 0.6786 - val_accuracy: 0.7271
#
# Epoch 127/500
#
# Epoch 00127: val_loss did not improve from 0.66327
# 13/13 - 2s - loss: 0.8006 - accuracy: 0.6924 - val_loss: 0.6649 - val_accuracy: 0.7290
#
# Epoch 128/500
#
# Epoch 00128: val_loss improved from 0.66327 to 0.65814, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.8252 - accuracy: 0.6793 - val_loss: 0.6581 - val_accuracy: 0.7336
#
# Epoch 129/500
#
# Epoch 00129: val_loss did not improve from 0.65814
# 13/13 - 2s - loss: 0.8221 - accuracy: 0.6776 - val_loss: 0.6904 - val_accuracy: 0.7373
#
# Epoch 130/500
#
# Epoch 00130: val_loss did not improve from 0.65814
# 13/13 - 2s - loss: 0.9446 - accuracy: 0.6303 - val_loss: 0.7175 - val_accuracy: 0.7188
#
# Epoch 131/500
#
# Epoch 00131: val_loss did not improve from 0.65814
# 13/13 - 2s - loss: 0.8428 - accuracy: 0.6674 - val_loss: 0.7291 - val_accuracy: 0.6984
#
# Epoch 132/500
#
# Epoch 00132: val_loss did not improve from 0.65814
# 13/13 - 2s - loss: 0.8597 - accuracy: 0.6602 - val_loss: 0.6841 - val_accuracy: 0.7308
#
# Epoch 133/500
#
# Epoch 00133: val_loss did not improve from 0.65814
# 13/13 - 2s - loss: 0.8273 - accuracy: 0.6773 - val_loss: 0.6661 - val_accuracy: 0.7364
#
# Epoch 134/500
#
# Epoch 00134: val_loss did not improve from 0.65814
# 13/13 - 2s - loss: 0.8304 - accuracy: 0.6748 - val_loss: 0.6707 - val_accuracy: 0.7401
#
# Epoch 135/500
#
# Epoch 00135: val_loss did not improve from 0.65814
# 13/13 - 2s - loss: 0.8298 - accuracy: 0.6834 - val_loss: 0.6910 - val_accuracy: 0.7216
#
# Epoch 136/500
#
# Epoch 00136: val_loss did not improve from 0.65814
# 13/13 - 2s - loss: 0.8163 - accuracy: 0.6847 - val_loss: 0.6804 - val_accuracy: 0.7234
#
# Epoch 137/500
#
# Epoch 00137: val_loss did not improve from 0.65814
# 13/13 - 2s - loss: 0.8228 - accuracy: 0.6862 - val_loss: 0.6633 - val_accuracy: 0.7336
#
# Epoch 138/500
#
# Epoch 00138: val_loss did not improve from 0.65814
# 13/13 - 2s - loss: 0.8324 - accuracy: 0.6741 - val_loss: 0.6670 - val_accuracy: 0.7447
#
# Epoch 139/500
#
# Epoch 00139: val_loss did not improve from 0.65814
# 13/13 - 2s - loss: 0.8220 - accuracy: 0.6785 - val_loss: 0.7028 - val_accuracy: 0.7095
#
# Epoch 140/500
#
# Epoch 00140: val_loss did not improve from 0.65814
# 13/13 - 2s - loss: 0.8169 - accuracy: 0.6859 - val_loss: 0.6774 - val_accuracy: 0.7419
#
# Epoch 141/500
#
# Epoch 00141: val_loss did not improve from 0.65814
# 13/13 - 2s - loss: 0.8116 - accuracy: 0.6865 - val_loss: 0.6828 - val_accuracy: 0.7253
#
# Epoch 142/500
#
# Epoch 00142: val_loss did not improve from 0.65814
# 13/13 - 2s - loss: 0.8152 - accuracy: 0.6836 - val_loss: 0.6627 - val_accuracy: 0.7345
#
# Epoch 143/500
#
# Epoch 00143: val_loss did not improve from 0.65814
# 13/13 - 2s - loss: 0.8313 - accuracy: 0.6722 - val_loss: 0.6695 - val_accuracy: 0.7280
#
# Epoch 144/500
#
# Epoch 00144: val_loss did not improve from 0.65814
# 13/13 - 2s - loss: 0.8394 - accuracy: 0.6714 - val_loss: 0.6902 - val_accuracy: 0.7179
#
# Epoch 145/500
#
# Epoch 00145: val_loss improved from 0.65814 to 0.65245, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 3s - loss: 0.8189 - accuracy: 0.6776 - val_loss: 0.6525 - val_accuracy: 0.7456
#
# Epoch 146/500
#
# Epoch 00146: val_loss did not improve from 0.65245
# 13/13 - 2s - loss: 0.8097 - accuracy: 0.6851 - val_loss: 0.6792 - val_accuracy: 0.7216
#
# Epoch 147/500
#
# Epoch 00147: val_loss did not improve from 0.65245
# 13/13 - 2s - loss: 0.8195 - accuracy: 0.6790 - val_loss: 0.6614 - val_accuracy: 0.7419
#
# Epoch 148/500
#
# Epoch 00148: val_loss did not improve from 0.65245
# 13/13 - 2s - loss: 0.8096 - accuracy: 0.6887 - val_loss: 0.7159 - val_accuracy: 0.7262
#
# Epoch 149/500
#
# Epoch 00149: val_loss did not improve from 0.65245
# 13/13 - 2s - loss: 0.8036 - accuracy: 0.6887 - val_loss: 0.7029 - val_accuracy: 0.7012
#
# Epoch 150/500
#
# Epoch 00150: val_loss did not improve from 0.65245
# 13/13 - 2s - loss: 0.7967 - accuracy: 0.6884 - val_loss: 0.6808 - val_accuracy: 0.7336
#
# Epoch 151/500
#
# Epoch 00151: val_loss did not improve from 0.65245
# 13/13 - 2s - loss: 0.8128 - accuracy: 0.6865 - val_loss: 0.7242 - val_accuracy: 0.6809
#
# Epoch 152/500
#
# Epoch 00152: val_loss did not improve from 0.65245
# 13/13 - 2s - loss: 0.8451 - accuracy: 0.6576 - val_loss: 0.6783 - val_accuracy: 0.7410
#
# Epoch 153/500
#
# Epoch 00153: val_loss did not improve from 0.65245
# 13/13 - 2s - loss: 0.8050 - accuracy: 0.6871 - val_loss: 0.6564 - val_accuracy: 0.7410
#
# Epoch 154/500
#
# Epoch 00154: val_loss did not improve from 0.65245
# 13/13 - 2s - loss: 0.8124 - accuracy: 0.6901 - val_loss: 0.7016 - val_accuracy: 0.7225
#
# Epoch 155/500
#
# Epoch 00155: val_loss did not improve from 0.65245
# 13/13 - 2s - loss: 0.8287 - accuracy: 0.6774 - val_loss: 0.6813 - val_accuracy: 0.7068
#
# Epoch 156/500
#
# Epoch 00156: val_loss did not improve from 0.65245
# 13/13 - 2s - loss: 0.8014 - accuracy: 0.6893 - val_loss: 0.6641 - val_accuracy: 0.7456
#
# Epoch 157/500
#
# Epoch 00157: val_loss did not improve from 0.65245
# 13/13 - 2s - loss: 0.8140 - accuracy: 0.6764 - val_loss: 0.6603 - val_accuracy: 0.7299
#
# Epoch 158/500
#
# Epoch 00158: val_loss did not improve from 0.65245
# 13/13 - 2s - loss: 0.8078 - accuracy: 0.6876 - val_loss: 0.6686 - val_accuracy: 0.7447
#
# Epoch 159/500
#
# Epoch 00159: val_loss did not improve from 0.65245
# 13/13 - 2s - loss: 0.8064 - accuracy: 0.6875 - val_loss: 0.6652 - val_accuracy: 0.7558
#
# Epoch 160/500
#
# Epoch 00160: val_loss did not improve from 0.65245
# 13/13 - 2s - loss: 0.8288 - accuracy: 0.6802 - val_loss: 0.7063 - val_accuracy: 0.7271
#
# Epoch 161/500
#
# Epoch 00161: val_loss did not improve from 0.65245
# 13/13 - 2s - loss: 0.8182 - accuracy: 0.6861 - val_loss: 0.6888 - val_accuracy: 0.7271
#
# Epoch 162/500
#
# ...
# 13/13 - 2s - loss: 0.7358 - accuracy: 0.7153 - val_loss: 0.6628 - val_accuracy: 0.7354
#
# Epoch 55/500
#
# Epoch 00055: val_loss did not improve from 0.63795
# 13/13 - 2s - loss: 0.7288 - accuracy: 0.7219 - val_loss: 0.6460 - val_accuracy: 0.7475
#
# Epoch 56/500
#
# Epoch 00056: val_loss did not improve from 0.63795
# 13/13 - 2s - loss: 0.7202 - accuracy: 0.7295 - val_loss: 0.6626 - val_accuracy: 0.7447
#
# Epoch 57/500
#
# Epoch 00057: val_loss did not improve from 0.63795
# 13/13 - 2s - loss: 0.7127 - accuracy: 0.7284 - val_loss: 0.6508 - val_accuracy: 0.7428
#
# Epoch 58/500
#
# Epoch 00058: val_loss did not improve from 0.63795
# 13/13 - 2s - loss: 0.7144 - accuracy: 0.7264 - val_loss: 0.6623 - val_accuracy: 0.7354
#
# Epoch 59/500
#
# Epoch 00059: val_loss did not improve from 0.63795
# 13/13 - 2s - loss: 0.7114 - accuracy: 0.7289 - val_loss: 0.6549 - val_accuracy: 0.7549
#
# Epoch 60/500
#
# Epoch 00060: val_loss did not improve from 0.63795
# 13/13 - 2s - loss: 0.7138 - accuracy: 0.7289 - val_loss: 0.6432 - val_accuracy: 0.7493
#
# Epoch 61/500
#
# Epoch 00061: val_loss did not improve from 0.63795
# 13/13 - 2s - loss: 0.7140 - accuracy: 0.7244 - val_loss: 0.6492 - val_accuracy: 0.7512
#
# Epoch 62/500
#
# Epoch 00062: val_loss did not improve from 0.63795
# 13/13 - 2s - loss: 0.7099 - accuracy: 0.7272 - val_loss: 0.6529 - val_accuracy: 0.7530
#
# Epoch 63/500
#
# Epoch 00063: val_loss did not improve from 0.63795
# 13/13 - 2s - loss: 0.7122 - accuracy: 0.7242 - val_loss: 0.6482 - val_accuracy: 0.7521
#
# Epoch 64/500
#
# Epoch 00064: val_loss did not improve from 0.63795
# 13/13 - 2s - loss: 0.7097 - accuracy: 0.7258 - val_loss: 0.6402 - val_accuracy: 0.7428
#
# Epoch 65/500
#
# Epoch 00065: val_loss did not improve from 0.63795
# 13/13 - 2s - loss: 0.7139 - accuracy: 0.7241 - val_loss: 0.6432 - val_accuracy: 0.7475
#
# Epoch 66/500
#
# Epoch 00066: val_loss did not improve from 0.63795
# 13/13 - 2s - loss: 0.7114 - accuracy: 0.7266 - val_loss: 0.6381 - val_accuracy: 0.7502
#
# Epoch 67/500
#
# Epoch 00067: val_loss did not improve from 0.63795
# 13/13 - 2s - loss: 0.7043 - accuracy: 0.7279 - val_loss: 0.6474 - val_accuracy: 0.7558
#
# Epoch 68/500
#
# Epoch 00068: val_loss did not improve from 0.63795
# 13/13 - 2s - loss: 0.7005 - accuracy: 0.7336 - val_loss: 0.6493 - val_accuracy: 0.7465
#
# Epoch 69/500
#
# Epoch 00069: val_loss did not improve from 0.63795
# 13/13 - 2s - loss: 0.7038 - accuracy: 0.7296 - val_loss: 0.6412 - val_accuracy: 0.7484
#
# Epoch 70/500
#
# Epoch 00070: val_loss improved from 0.63795 to 0.63663, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.6977 - accuracy: 0.7343 - val_loss: 0.6366 - val_accuracy: 0.7530
#
# Epoch 71/500
#
# Epoch 00071: val_loss did not improve from 0.63663
# 13/13 - 2s - loss: 0.6994 - accuracy: 0.7361 - val_loss: 0.6466 - val_accuracy: 0.7438
#
# Epoch 72/500
#
# Epoch 00072: val_loss did not improve from 0.63663
# 13/13 - 2s - loss: 0.7046 - accuracy: 0.7289 - val_loss: 0.6424 - val_accuracy: 0.7530
#
# Epoch 73/500
#
# Epoch 00073: val_loss did not improve from 0.63663
# 13/13 - 2s - loss: 0.6954 - accuracy: 0.7363 - val_loss: 0.6431 - val_accuracy: 0.7521
#
# Epoch 74/500
#
# Epoch 00074: val_loss did not improve from 0.63663
# 13/13 - 2s - loss: 0.7031 - accuracy: 0.7267 - val_loss: 0.6435 - val_accuracy: 0.7475
#
# Epoch 75/500
#
# Epoch 00075: val_loss improved from 0.63663 to 0.62950, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.6940 - accuracy: 0.7375 - val_loss: 0.6295 - val_accuracy: 0.7475
#
# Epoch 76/500
#
# Epoch 00076: val_loss did not improve from 0.62950
# 13/13 - 2s - loss: 0.6994 - accuracy: 0.7319 - val_loss: 0.6370 - val_accuracy: 0.7493
#
# Epoch 77/500
#
# Epoch 00077: val_loss did not improve from 0.62950
# 13/13 - 2s - loss: 0.6969 - accuracy: 0.7309 - val_loss: 0.6352 - val_accuracy: 0.7512
#
# Epoch 78/500
#
# Epoch 00078: val_loss did not improve from 0.62950
# 13/13 - 2s - loss: 0.6951 - accuracy: 0.7313 - val_loss: 0.6352 - val_accuracy: 0.7558
#
# Epoch 79/500
#
# Epoch 00079: val_loss did not improve from 0.62950
# 13/13 - 2s - loss: 0.6828 - accuracy: 0.7447 - val_loss: 0.6459 - val_accuracy: 0.7530
#
# Epoch 80/500
#
# Epoch 00080: val_loss did not improve from 0.62950
# 13/13 - 2s - loss: 0.6833 - accuracy: 0.7427 - val_loss: 0.6320 - val_accuracy: 0.7567
#
# Epoch 81/500
#
# Epoch 00081: val_loss did not improve from 0.62950
# 13/13 - 2s - loss: 0.6903 - accuracy: 0.7398 - val_loss: 0.6407 - val_accuracy: 0.7502
#
# Epoch 82/500
#
# Epoch 00082: val_loss did not improve from 0.62950
# 13/13 - 2s - loss: 0.6824 - accuracy: 0.7372 - val_loss: 0.6430 - val_accuracy: 0.7475
#
# Epoch 83/500
#
# Epoch 00083: val_loss did not improve from 0.62950
# 13/13 - 2s - loss: 0.6840 - accuracy: 0.7386 - val_loss: 0.6353 - val_accuracy: 0.7539
#
# Epoch 84/500
#
# Epoch 00084: val_loss did not improve from 0.62950
# 13/13 - 2s - loss: 0.6866 - accuracy: 0.7384 - val_loss: 0.6391 - val_accuracy: 0.7549
#
# Epoch 85/500
#
# Epoch 00085: val_loss did not improve from 0.62950
# 13/13 - 2s - loss: 0.6875 - accuracy: 0.7378 - val_loss: 0.6319 - val_accuracy: 0.7484
#
# Epoch 86/500
#
# Epoch 00086: val_loss did not improve from 0.62950
# 13/13 - 2s - loss: 0.6931 - accuracy: 0.7347 - val_loss: 0.6318 - val_accuracy: 0.7558
#
# Epoch 87/500
#
# Epoch 00087: val_loss did not improve from 0.62950
# 13/13 - 2s - loss: 0.6881 - accuracy: 0.7381 - val_loss: 0.6317 - val_accuracy: 0.7465
#
# Epoch 88/500
#
# Epoch 00088: val_loss did not improve from 0.62950
# 13/13 - 2s - loss: 0.6878 - accuracy: 0.7389 - val_loss: 0.6554 - val_accuracy: 0.7364
#
# Epoch 89/500
#
# Epoch 00089: val_loss improved from 0.62950 to 0.62837, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 2s - loss: 0.6780 - accuracy: 0.7440 - val_loss: 0.6284 - val_accuracy: 0.7502
#
# Epoch 90/500
#
# Epoch 00090: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6853 - accuracy: 0.7369 - val_loss: 0.6309 - val_accuracy: 0.7447
#
# Epoch 91/500
#
# Epoch 00091: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6767 - accuracy: 0.7406 - val_loss: 0.6416 - val_accuracy: 0.7336
#
# Epoch 92/500
#
# Epoch 00092: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6754 - accuracy: 0.7436 - val_loss: 0.6366 - val_accuracy: 0.7438
#
# Epoch 93/500
#
# Epoch 00093: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6712 - accuracy: 0.7418 - val_loss: 0.6362 - val_accuracy: 0.7484
#
# Epoch 94/500
#
# Epoch 00094: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6812 - accuracy: 0.7457 - val_loss: 0.6362 - val_accuracy: 0.7567
#
# Epoch 95/500
#
# Epoch 00095: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6776 - accuracy: 0.7400 - val_loss: 0.6414 - val_accuracy: 0.7438
#
# Epoch 96/500
#
# Epoch 00096: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6801 - accuracy: 0.7366 - val_loss: 0.6286 - val_accuracy: 0.7456
#
# Epoch 97/500
#
# Epoch 00097: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6835 - accuracy: 0.7393 - val_loss: 0.6364 - val_accuracy: 0.7447
#
# Epoch 98/500
#
# Epoch 00098: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6782 - accuracy: 0.7487 - val_loss: 0.6610 - val_accuracy: 0.7465
#
# Epoch 99/500
#
# Epoch 00099: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6934 - accuracy: 0.7373 - val_loss: 0.6336 - val_accuracy: 0.7502
#
# Epoch 100/500
#
# Epoch 00100: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6739 - accuracy: 0.7410 - val_loss: 0.6426 - val_accuracy: 0.7484
#
# Epoch 101/500
#
# Epoch 00101: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6762 - accuracy: 0.7444 - val_loss: 0.6350 - val_accuracy: 0.7493
#
# Epoch 102/500
#
# Epoch 00102: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6643 - accuracy: 0.7515 - val_loss: 0.6331 - val_accuracy: 0.7493
#
# Epoch 103/500
#
# Epoch 00103: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6773 - accuracy: 0.7375 - val_loss: 0.6309 - val_accuracy: 0.7438
#
# Epoch 104/500
#
# Epoch 00104: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6741 - accuracy: 0.7449 - val_loss: 0.6588 - val_accuracy: 0.7382
#
# Epoch 105/500
#
# Epoch 00105: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6756 - accuracy: 0.7420 - val_loss: 0.6410 - val_accuracy: 0.7484
#
# Epoch 106/500
#
# Epoch 00106: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6719 - accuracy: 0.7432 - val_loss: 0.6287 - val_accuracy: 0.7484
#
# Epoch 107/500
#
# Epoch 00107: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6617 - accuracy: 0.7520 - val_loss: 0.6383 - val_accuracy: 0.7530
#
# Epoch 108/500
#
# Epoch 00108: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6621 - accuracy: 0.7486 - val_loss: 0.6451 - val_accuracy: 0.7493
#
# Epoch 109/500
#
# Epoch 00109: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6736 - accuracy: 0.7423 - val_loss: 0.6379 - val_accuracy: 0.7475
#
# Epoch 110/500
#
# Epoch 00110: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6737 - accuracy: 0.7446 - val_loss: 0.6359 - val_accuracy: 0.7530
#
# Epoch 111/500
#
# Epoch 00111: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6628 - accuracy: 0.7521 - val_loss: 0.6408 - val_accuracy: 0.7493
#
# Epoch 112/500
#
# Epoch 00112: val_loss did not improve from 0.62837
# 13/13 - 2s - loss: 0.6635 - accuracy: 0.7507 - val_loss: 0.6527 - val_accuracy: 0.7521
#
# Epoch 113/500
#
# Epoch 00113: val_loss improved from 0.62837 to 0.62410, saving model to /content/drive/My Drive/Doutorado/[DL] Projeto/models/best_model-12-12es_best.h5
# 13/13 - 3s - loss: 0.6699 - accuracy: 0.7447 - val_loss: 0.6241 - val_accuracy: 0.7410
#
# Epoch 114/500
#
# Epoch 00114: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6604 - accuracy: 0.7450 - val_loss: 0.6308 - val_accuracy: 0.7502
#
# Epoch 115/500
#
# Epoch 00115: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6573 - accuracy: 0.7467 - val_loss: 0.6312 - val_accuracy: 0.7428
#
# Epoch 116/500
#
# Epoch 00116: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6671 - accuracy: 0.7484 - val_loss: 0.6443 - val_accuracy: 0.7465
#
# Epoch 117/500
#
# Epoch 00117: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6657 - accuracy: 0.7446 - val_loss: 0.6411 - val_accuracy: 0.7447
#
# Epoch 118/500
#
# Epoch 00118: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6618 - accuracy: 0.7506 - val_loss: 0.6363 - val_accuracy: 0.7428
#
# Epoch 119/500
#
# Epoch 00119: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6688 - accuracy: 0.7452 - val_loss: 0.6284 - val_accuracy: 0.7475
#
# Epoch 120/500
#
# Epoch 00120: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6540 - accuracy: 0.7532 - val_loss: 0.6708 - val_accuracy: 0.7475
#
# Epoch 121/500
#
# Epoch 00121: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6810 - accuracy: 0.7393 - val_loss: 0.6347 - val_accuracy: 0.7447
#
# Epoch 122/500
#
# Epoch 00122: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6553 - accuracy: 0.7527 - val_loss: 0.6366 - val_accuracy: 0.7502
#
# Epoch 123/500
#
# Epoch 00123: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6512 - accuracy: 0.7558 - val_loss: 0.6435 - val_accuracy: 0.7456
#
# Epoch 124/500
#
# Epoch 00124: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6600 - accuracy: 0.7453 - val_loss: 0.6486 - val_accuracy: 0.7549
#
# Epoch 125/500
#
# Epoch 00125: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6610 - accuracy: 0.7500 - val_loss: 0.6327 - val_accuracy: 0.7447
#
# Epoch 126/500
#
# Epoch 00126: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6499 - accuracy: 0.7600 - val_loss: 0.6377 - val_accuracy: 0.7428
#
# Epoch 127/500
#
# Epoch 00127: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6530 - accuracy: 0.7537 - val_loss: 0.6521 - val_accuracy: 0.7465
#
# Epoch 128/500
#
# Epoch 00128: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6597 - accuracy: 0.7477 - val_loss: 0.6440 - val_accuracy: 0.7484
#
# Epoch 129/500
#
# Epoch 00129: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6519 - accuracy: 0.7537 - val_loss: 0.6620 - val_accuracy: 0.7447
#
# Epoch 130/500
#
# Epoch 00130: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6708 - accuracy: 0.7470 - val_loss: 0.6368 - val_accuracy: 0.7512
#
# Epoch 131/500
#
# Epoch 00131: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6496 - accuracy: 0.7515 - val_loss: 0.6359 - val_accuracy: 0.7484
#
# Epoch 132/500
#
# Epoch 00132: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6445 - accuracy: 0.7604 - val_loss: 0.6331 - val_accuracy: 0.7558
#
# Epoch 133/500
#
# Epoch 00133: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6489 - accuracy: 0.7569 - val_loss: 0.6331 - val_accuracy: 0.7539
#
# Epoch 134/500
#
# Epoch 00134: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6563 - accuracy: 0.7501 - val_loss: 0.6365 - val_accuracy: 0.7475
#
# Epoch 135/500
#
# Epoch 00135: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6559 - accuracy: 0.7535 - val_loss: 0.6393 - val_accuracy: 0.7502
#
# Epoch 136/500
#
# Epoch 00136: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6613 - accuracy: 0.7477 - val_loss: 0.6517 - val_accuracy: 0.7475
#
# Epoch 137/500
#
# Epoch 00137: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6523 - accuracy: 0.7529 - val_loss: 0.6464 - val_accuracy: 0.7345
#
# Epoch 138/500
#
# Epoch 00138: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6431 - accuracy: 0.7644 - val_loss: 0.6489 - val_accuracy: 0.7549
#
# Epoch 139/500
#
# Epoch 00139: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6567 - accuracy: 0.7523 - val_loss: 0.6374 - val_accuracy: 0.7493
#
# Epoch 140/500
#
# Epoch 00140: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6472 - accuracy: 0.7523 - val_loss: 0.6362 - val_accuracy: 0.7447
#
# Epoch 141/500
#
# Epoch 00141: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6388 - accuracy: 0.7589 - val_loss: 0.6302 - val_accuracy: 0.7521
#
# Epoch 142/500
#
# Epoch 00142: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6391 - accuracy: 0.7594 - val_loss: 0.6313 - val_accuracy: 0.7521
#
# Epoch 143/500
#
# Epoch 00143: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6393 - accuracy: 0.7552 - val_loss: 0.6780 - val_accuracy: 0.7364
#
# Epoch 144/500
#
# Epoch 00144: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6628 - accuracy: 0.7513 - val_loss: 0.6350 - val_accuracy: 0.7465
#
# Epoch 145/500
#
# Epoch 00145: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6379 - accuracy: 0.7634 - val_loss: 0.6294 - val_accuracy: 0.7539
#
# Epoch 146/500
#
# Epoch 00146: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6470 - accuracy: 0.7569 - val_loss: 0.6289 - val_accuracy: 0.7521
#
# Epoch 147/500
#
# Epoch 00147: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6579 - accuracy: 0.7489 - val_loss: 0.6821 - val_accuracy: 0.7354
#
# Epoch 148/500
#
# Epoch 00148: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6609 - accuracy: 0.7460 - val_loss: 0.6455 - val_accuracy: 0.7345
#
# Epoch 149/500
#
# Epoch 00149: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6316 - accuracy: 0.7641 - val_loss: 0.6406 - val_accuracy: 0.7438
#
# Epoch 150/500
#
# Epoch 00150: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6434 - accuracy: 0.7592 - val_loss: 0.6382 - val_accuracy: 0.7502
#
# Epoch 151/500
#
# Epoch 00151: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6381 - accuracy: 0.7626 - val_loss: 0.6360 - val_accuracy: 0.7428
#
# Epoch 152/500
#
# Epoch 00152: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6399 - accuracy: 0.7546 - val_loss: 0.6415 - val_accuracy: 0.7401
#
# Epoch 153/500
#
# Epoch 00153: val_loss did not improve from 0.62410
# 13/13 - 2s - loss: 0.6450 - accuracy: 0.7604 - val_loss: 0.6327 - val_accuracy: 0.7364
#
# Epoch 00153: early stopping
# Test accuracy:
# 0.7425131
# 100%|██████████| 10/10 [1:44:07<00:00, 600.16s/trial, best loss: -0.742513120174408]
# Best performing model chosen hyper-parameters:
# {'rate': 0.587606728324542, 'rate_1': 0.3746350041674067, 'rate_2': 0.5838315653286106, 'units': 4, 'units_1': 3}

# %%
def split_label(dataset):
    batches = []
    labels = []
    for d in dataset:
        batches.append([np.array(d[0], dtype='float32'), np.array(d[1], dtype='int32'), 
                        np.array(d[2], dtype='int32'), np.array(d[3], dtype='int32')])
        labels.append(d[4])
        
    return np.array(batches), np.array(labels)

def getPdata(data):
    
    p_one = []
    p_two = []
    
    for bag in data['test']:
        if len(bag['X']) < 2: continue
        
        indx = list(range(len(bag['X'])))
        random.shuffle(indx)
        
        p_one.append({
            'embeds':   [bag['embeds'][indx[0]]],
            'ProbY': 	[bag['ProbY'][indx[0]]],
            'Y':    	bag['Y'],
            'SubType':	bag['SubType'],
            'ObjType':	bag['ObjType']
        })

        p_two.append({
            'embeds':   [bag['embeds'][indx[0]], bag['embeds'][indx[1]]],
            'ProbY': 	[bag['ProbY'][indx[0]], bag['ProbY'][indx[1]]],
            'Y':   	 	bag['Y'],
            'SubType':	bag['SubType'],
            'ObjType':	bag['ObjType']
        })
    
    
    return getData(p_one), getData(p_two)


def getPscore(p_n_data):
    
    data_one, y_true = split_label(p_n_data)

    y_pred_indx = []
    y_pred_prob = []
    for bert, alias, subj, obj in data_one:
        prediction = model.predict([[bert], [alias], [subj], [obj]])
        y_pred_indx.append(np.argmax(prediction))
        y_pred_prob.append(np.amax(prediction))
    
    y_pred_indx = np.array(y_pred_indx)
    y_prob = np.reshape(np.array(y_pred_prob), (-1))
    y_true = np.reshape(np.array(y_true), (-1))
    order = np.argsort(-y_prob)
    
    def p_score(n):
        sum_correct_pred = 0.0
        for i in order[:n]:
            sum_correct_pred += 1.0 if (y_true[i] == y_pred_indx[i]) else 0
        return sum_correct_pred / n
        
    return p_score(100), p_score(200), p_score(300)

def savePredictions2File(dataset_name, algorithm_name, data):
    validation, count_bags, alias_count = getData(data['test'])
    classes_ = len(data['rel2id'])
    
    data, y_true = split_label(validation)

    logit_list = []
    for bert, alias, subj, obj in data:
        logit_list.append((model.predict([[bert], [alias], [subj], [obj]])[0]).tolist())

    y_flatten = y_true.flatten().tolist()
    y_actual_hot = (tf.keras.utils.to_categorical(y_flatten, num_classes=classes_)).tolist()
    
    pickle.dump({'logit_list': logit_list, 'y_hot': y_actual_hot}, 
                open(results_dir + "{}/{}/precision_recall.pkl".format(dataset_name, algorithm_name), 'wb'))

# %%
def getPRData4BERTSIDE():
  model = tf.keras.models.load_model(models_dir + model_name + '.h5')

  data = pickle.load(open(path2datafile, 'rb'))

  validation, count_bags, _ = getData(data['test'])

  data, y_true = split_label(validation)

  y_pred = []
  y_scores = []
  for bert, alias, subj, obj in data:
    score = model.predict([[bert], [alias], [subj], [obj]])
    y_scores.append(score[0].tolist())
    y_pred.append(np.argmax(score))

  y_pred = np.array(y_pred)
  print(y_pred.shape)

  y_flatten = y_true.flatten().tolist()
  y_true = (tf.keras.utils.to_categorical(y_flatten, num_classes=5)).tolist()

  y_hot 	   	= np.array(y_true)
  logit_list 	= np.array(y_scores)

  y_hot_new       = np.reshape(np.array([x[1:] for x in y_hot]), (-1))
  logit_list_new  = np.reshape(np.array([x[1:] for x in logit_list]), (-1))

  return y_hot_new, logit_list_new

def getPRCurveAndAUC(y_hot, logit_list):
  precision, recall, thresholds = precision_recall_curve(y_hot, logit_list)
  area_under = average_precision_score(y_hot, logit_list)
  return precision, recall, thresholds, area_under

def loadBaselinesData(path):
	preds 	   	= pickle.load(open(path, 'rb'))
	y_hot 	   	= np.array(preds['y_hot'])
	logit_list 	= np.array(preds['logit_list'])
	y_hot_new       = np.reshape(np.array([x[1:] for x in y_hot]),      (-1))
	logit_list_new  = np.reshape(np.array([x[1:] for x in logit_list]), (-1))
	return y_hot_new, logit_list_new

# %%
y_hot, logit_list = loadBaselinesData(results_dir + "BERT-SIDE/precision_recall.pkl")  #getPRData4BERTSIDE()
precision, recall, thresholds, area_under = getPRCurveAndAUC(y_hot, logit_list)

# summarize scores
print('BERT-SIDE auc=%.3f' % (area_under))

# plot the precision-recall curves for BERT-SIDE
plt.plot(recall[:], precision[:], marker='o',  color='red' ,label='BERT-SIDE', markevery = 0.1, ms = 6,  lw=1)

y_hot, logit_list = loadBaselinesData(results_dir + "BGWA/precision_recall.pkl")
precision, recall, thresholds, area_under = getPRCurveAndAUC(y_hot, logit_list)
plt.plot(recall[:], precision[:], marker='d', color='purple' ,label='BGWA', markevery = 0.1, ms = 6,  lw=1)

y_hot, logit_list = loadBaselinesData(results_dir + "RESIDE/precision_recall.pkl")
precision, recall, thresholds, area_under = getPRCurveAndAUC(y_hot, logit_list)
plt.plot(recall[:], precision[:], marker='s', color='darkorange' , label='RESIDE', markevery = 0.1, ms = 6,  lw=1)

# axis labels
plt.xlabel('Recall', fontsize=14)
plt.ylabel('Precision', fontsize=14)
# show the legend
plt.legend(loc="lower left", prop = {'size' : 12})
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# BERT-SIDE auc=0.819

# %%
model = tf.keras.models.load_model(models_dir + model_name + '.h5')

data = pickle.load(open(path2datafile, 'rb'))

print("Save data to plot precision-recall curve")

savePredictions2File("gids", "BERT-SIDE", data)

print("precision_recall.pkl created")

print("\nP@N results")

one_, two_ = getPdata(data)

one, one_bags_count, _ = one_
two, two_bags_count, _ = two_

print('=============== test one =============================')
one_100, one_200, one_300 = getPscore(one)
print("P@100: {}, P@200: {}, P@300: {}".format(one_100, one_200, one_300))

print('=============== test two =============================')
two_100, two_200, two_300 = getPscore(two)
print("P@100: {}, P@200: {}, P@300: {}".format(two_100, two_200, two_300))

print('=============== test all =============================')
all_, count_bags, _ = getData(data['test'])
all_100, all_200, all_300 = getPscore(all_)
print("P@100: {}, P@200: {}, P@300: {}".format(all_100, all_200, all_300))
# Out:
# WARNING:tensorflow:Large dropout rate: 0.587607 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# /tensorflow-2.0.0/python3.6/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Save data to plot precision-recall curve
# precision_recall.pkl created
#
# P@N results
# =============== test one =============================
# P@100: 1.0, P@200: 0.99, P@300: 0.9533333333333334
# =============== test two =============================
# P@100: 1.0, P@200: 0.995, P@300: 0.99
# =============== test all =============================
# P@100: 1.0, P@200: 1.0, P@300: 1.0
